# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 4)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.scatterplot(df,x="TV" , y = "Sales",hue = df['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(df,x="Radio" , y = "Sales",hue = df['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(df,x="Newspaper" , y = "Sales",hue = df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
fig = plt.figure(figsize=(8,6))

# 3D axis
ax = fig.add_subplot(111, projection='3d')

# Plot
ax.scatter(df['TV'], df['Radio'], df['Sales'])

# Labels
ax.set_xlabel("TV")
ax.set_ylabel("Radio")
ax.set_zlabel("Sales")

plt.show()

# %%
X = df.drop(columns = ["Sales"],axis = True)

# %%
y = df["Sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_train
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
# 79     11.0
# 197    14.8
# 38     10.1
# 24      9.7
# 122    16.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    17.6
# 102    19.8
# Name: Sales, Length: 160, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
models = {
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "XGB Regressor": xgb.XGBRegressor(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
}

# %%
results = []

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test,y_pred)
    results.append({
        'Model': name,
        'r2 Score': round(r2, 4),
    })

# %%
results
# Out:
# [{'Model': 'Random Forest', 'r2 Score': 0.9535},
#  {'Model': 'Gradient Boosting', 'r2 Score': 0.9594},
#  {'Model': 'XGB Regressor', 'r2 Score': 0.9529}]

# %%
import joblib
joblib.dump(models['Gradient Boosting'],'GB_model.pkl')
joblib.dump(X.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
